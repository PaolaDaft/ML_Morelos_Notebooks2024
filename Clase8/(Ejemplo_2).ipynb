# %% [markdown]
# <a href="https://colab.research.google.com/github/PaolaDaft/ML_Morelos_Notebooks2024/blob/main/Clase8/(Ejemplo_2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
from mpl_toolkits import mplot3d
from hdbscan import HDBSCAN

#https://anaconda.org/conda-forge/hdbscan
#conda install -c conda-forge hdbscan

# %%
#Cargamos el dataframe
df_cluster_hdbscan = np.load('C:/Users/layla/Escritorio/Lay/Docencia/RiskMathics/Data Science y Machine Learning - Casos de Uso y Aplicaciones/4. Sesion/Algoritmos de Agrupacion I/Datos/clusterable_data.npy')

# %%
#Instanciamos el algoritmo
hdbscan = HDBSCAN(min_cluster_size=20,
                 min_samples=10)

#Entrenamos y predecimos
preds = hdbscan.fit_predict(df_cluster_hdbscan)

# %%
#Convertimos en dataframe para poder graficar!
df_cluster_hdbscan = pd.DataFrame(df_cluster_hdbscan)
df_cluster_hdbscan.head()
# Out:
#           0         1
# 0 -0.121535 -0.228763
# 1 -0.220937 -0.252511
# 2  0.125904 -0.273143
# 3 -0.164537 -0.222244
# 4 -0.180824 -0.211075

# %%
#Renombramos las columnas!
df_cluster_hdbscan = df_cluster_hdbscan.rename(columns={0:'x',
                                                       1:'y'})
df_cluster_hdbscan.columns
# Out:
# Index(['x', 'y'], dtype='object')

# %%
#Graficamos
df_cluster_hdbscan.plot(kind='scatter', x='x', y='y', c=preds, cmap='Accent_r', figsize=(16,10))
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %% [markdown]
# # Conclusiones
#
# En base a la visualización anterior, nuestro algoritmo nos ha creado seis clusters y nos ha detectado el ruido del dataset (puntos grises).
